# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.10-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Downloading psycopg2-2.9.10-cp310-cp310-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.2 MB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 0.8/1.2 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 1.9 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10

# %%
import psycopg2

connection = psycopg2.connect(
dbname='testdb',
user='postgres',
password='1234',
host='193.203.191.79',
port='32001'
)
query ="select * from users"

# %%
import pandas as pd
df= pd.read_sql(query, connection)
df.head(3)
# Out:
# C:\Users\deniz\AppData\Local\Temp\ipykernel_17396\2917992113.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql(query, connection)
#    id             name                      email  \
# 0   1   Raymond Howard     erodriguez@example.net
# 1   2  Robert Mccarthy  williamsjames@example.org
# 2   3     Sean Russell        linda46@example.org
#
#                                               review  rating
# 0  Partner trouble serious sign bar follow. Assum...     6.8
# 1  Truth region personal how position technology....     2.1
# 2  Figure news significant stock. Scientist voice...     2.9

# %%
connection.close()

# %%
df.shape
# Out:
# (4011, 5)

# %%
texts= df['review'].values
ratings =df['rating'].values

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from scikit-learn) (2.2.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from scikit-learn) (1.15.3)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 1.4 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/11.1 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.1 MB 1.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/11.1 MB 1.5 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.1 MB 1.5 MB/s eta 0:00:07
#    ------- -------------------------------- 2.1/11.1 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/11.1 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.1 MB 1.6 MB/s eta 0:00:06
#    ------------ --------------------------- 3.4/11.1 MB 1.6 MB/s eta 0:00:05
#    ------------- -------------------------- 3.7/11.1 MB 1.6 MB/s eta 0:00:05
#    --------------- ------------------------ 4.2/11.1 MB 1.6 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.5/11.1 MB 1.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.0/11.1 MB 1.7 MB/s eta 0:00:04
#    ------------------- -------------------- 5.5/11.1 MB 1.7 MB/s eta 0:00:04
#    --------------------- ------------------ 6.0/11.1 MB 1.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.3/11.1 MB 1.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.6/11.1 MB 1.7 MB/s eta 0:00:03
#    ------------------------ --------------- 6.8/11.1 MB 1.7 MB/s eta 0:00:03
#    ------------------------- -------------- 7.1/11.1 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 7.6/11.1 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.9/11.1 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/11.1 MB 1.7 MB/s eta 0:00:02
#    ------------------------------- -------- 8.7/11.1 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.1 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 9.4/11.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.1 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.1 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 1.7 MB/s eta 0:00:00
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed joblib-1.5.0 scikit-learn-1.6.1 threadpoolctl-3.6.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train, y_test = train_test_split(texts, ratings, test_size=0.3, random_state=42)

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from tensorflow) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow)
#   Using cached protobuf-5.29.4-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from tensorflow) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.71.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.9.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting numpy<2.2.0,>=1.26.0 (from tensorflow)
#   Downloading numpy-2.1.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.13.0-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp310-cp310-win_amd64.whl.metadata (22 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.5.0->tensorflow)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.0.9-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.15.0-cp310-cp310-win_amd64.whl.metadata (49 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.19.0-cp310-cp310-win_amd64.whl (375.7 MB)
#    ---------------------------------------- 0.0/375.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/375.7 MB ? eta -:--:--
#    ---------------------------------------- 1.0/375.7 MB 2.8 MB/s eta 0:02:14
#    ---------------------------------------- 1.6/375.7 MB 3.0 MB/s eta 0:02:05
#    ---------------------------------------- 2.4/375.7 MB 3.0 MB/s eta 0:02:06
#    ---------------------------------------- 3.4/375.7 MB 3.4 MB/s eta 0:01:50
#    ---------------------------------------- 4.2/375.7 MB 3.6 MB/s eta 0:01:44
#     --------------------------------------- 5.0/375.7 MB 3.6 MB/s eta 0:01:45
#     --------------------------------------- 5.5/375.7 MB 3.5 MB/s eta 0:01:45
#     --------------------------------------- 6.3/375.7 MB 3.4 MB/s eta 0:01:51
#     --------------------------------------- 7.1/375.7 MB 3.4 MB/s eta 0:01:48
#     --------------------------------------- 7.9/375.7 MB 3.6 MB/s eta 0:01:44
#     --------------------------------------- 8.9/375.7 MB 3.6 MB/s eta 0:01:43
#    - -------------------------------------- 9.7/375.7 MB 3.6 MB/s eta 0:01:42
#    - -------------------------------------- 10.7/375.7 MB 3.7 MB/s eta 0:01:39
#    - -------------------------------------- 11.5/375.7 MB 3.8 MB/s eta 0:01:37
#    - -------------------------------------- 12.6/375.7 MB 3.8 MB/s eta 0:01:35
#    - -------------------------------------- 13.6/375.7 MB 3.9 MB/s eta 0:01:33
#    - -------------------------------------- 14.4/375.7 MB 3.9 MB/s eta 0:01:33
#    - -------------------------------------- 14.9/375.7 MB 3.8 MB/s eta 0:01:35
#    - -------------------------------------- 15.7/375.7 MB 3.8 MB/s eta 0:01:34
#    - -------------------------------------- 16.5/375.7 MB 3.8 MB/s eta 0:01:34
#    - -------------------------------------- 17.3/375.7 MB 3.8 MB/s eta 0:01:35
#    - -------------------------------------- 17.8/375.7 MB 3.8 MB/s eta 0:01:35
#    - -------------------------------------- 18.4/375.7 MB 3.7 MB/s eta 0:01:36
#    -- ------------------------------------- 19.1/375.7 MB 3.7 MB/s eta 0:01:37
#    -- ------------------------------------- 19.7/375.7 MB 3.7 MB/s eta 0:01:38
#    -- ------------------------------------- 20.2/375.7 MB 3.6 MB/s eta 0:01:39
#    -- ------------------------------------- 20.7/375.7 MB 3.6 MB/s eta 0:01:40
#    -- ------------------------------------- 21.0/375.7 MB 3.5 MB/s eta 0:01:42
#    -- ------------------------------------- 21.2/375.7 MB 3.5 MB/s eta 0:01:42
#    -- ------------------------------------- 21.5/375.7 MB 3.3 MB/s eta 0:01:47
#    -- ------------------------------------- 22.5/375.7 MB 3.4 MB/s eta 0:01:45
#    -- ------------------------------------- 23.1/375.7 MB 3.4 MB/s eta 0:01:45
#    -- ------------------------------------- 23.9/375.7 MB 3.4 MB/s eta 0:01:45
#    -- ------------------------------------- 24.6/375.7 MB 3.4 MB/s eta 0:01:44
#    -- ------------------------------------- 25.7/375.7 MB 3.4 MB/s eta 0:01:43
#    -- ------------------------------------- 26.0/375.7 MB 3.4 MB/s eta 0:01:43
#    -- ------------------------------------- 27.0/375.7 MB 3.4 MB/s eta 0:01:43
#    -- ------------------------------------- 27.3/375.7 MB 3.4 MB/s eta 0:01:43
#    -- ------------------------------------- 27.5/375.7 MB 3.4 MB/s eta 0:01:44
#    -- ------------------------------------- 28.0/375.7 MB 3.3 MB/s eta 0:01:46
#    --- ------------------------------------ 28.6/375.7 MB 3.3 MB/s eta 0:01:47
#    --- ------------------------------------ 28.6/375.7 MB 3.3 MB/s eta 0:01:47
#    --- ------------------------------------ 28.8/375.7 MB 3.2 MB/s eta 0:01:50
#    --- ------------------------------------ 29.4/375.7 MB 3.2 MB/s eta 0:01:50
#    --- ------------------------------------ 29.9/375.7 MB 3.1 MB/s eta 0:01:50
#    --- ------------------------------------ 30.7/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 31.2/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 31.7/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 32.5/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 33.0/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 33.6/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 34.1/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 34.6/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 35.1/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 35.9/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 36.4/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 37.0/375.7 MB 3.1 MB/s eta 0:01:51
#    --- ------------------------------------ 37.5/375.7 MB 3.1 MB/s eta 0:01:51
#    ---- ----------------------------------- 38.3/375.7 MB 3.1 MB/s eta 0:01:51
#    ---- ----------------------------------- 38.5/375.7 MB 3.0 MB/s eta 0:01:51
#    ---- -----------------------------------
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    ---------------- ----------------------- 11/26 [numpy]
#    -------------------- ------------------- 13/26 [markdown]
#    --------------------- ------------------ 14/26 [grpcio]
#    --------------------- ------------------ 14/26 [grpcio]
#    ----------------------- ---------------- 15/26 [google-pasta]
#    --------------------------- ------------ 18/26 [absl-py]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    -------------------------------- ------- 21/26 [markdown-it-py]
#    -------------------------------- ------- 21/26 [markdown-it-py]
#    --------------------------------- ------ 22/26 [h5py]
#    --------------------------------- ------ 22/26 [h5py]
#    ----------------------------------- ---- 23/26 [rich]
#    ----------------------------------- ---- 23/26 [rich]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    ------------------------------------ --- 24/26 [keras]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    -------------------------------------- - 25/26 [tensorflow]
#    ---------------------------------------- 26/26 [tensorflow]
#
# Successfully installed absl-py-2.2.2 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.71.0 h5py-3.13.0 keras-3.9.2 libclang-18.1.1 markdown-3.8 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.1 namex-0.0.9 numpy-2.1.3 opt-einsum-3.4.0 optree-0.15.0 protobuf-5.29.4 rich-14.0.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-3.1.0 werkzeug-3.1.3 wrapt-1.17.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\deniz\anaconda3\envs\env_1\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\deniz\anaconda3\envs\env_1\Lib\site-packages\~umpy'.
#   You can safely remove it manually.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer= Tokenizer(num_words=10000, oov_token='<OOV>')
tokenizer.fit_on_texts(X_train)

# %%
tokenizer.word_index
# Out:
# {'<OOV>': 1,
#  'visit': 2,
#  'detail': 3,
#  'purpose': 4,
#  'thing': 5,
#  'perform': 6,
#  'already': 7,
#  'lawyer': 8,
#  'store': 9,
#  'society': 10,
#  'key': 11,
#  'fast': 12,
#  'lead': 13,
#  'kind': 14,
#  'fill': 15,
#  'deal': 16,
#  'would': 17,
#  'occur': 18,
#  'nothing': 19,
#  'ready': 20,
#  'break': 21,
#  'card': 22,
#  'how': 23,
#  'character': 24,
#  'policy': 25,
#  'security': 26,
#  'yeah': 27,
#  'election': 28,
#  'agree': 29,
#  'lay': 30,
#  'letter': 31,
#  'up': 32,
#  'realize': 33,
#  'meeting': 34,
#  'head': 35,
#  'performance': 36,
#  'mouth': 37,
#  'site': 38,
#  'far': 39,
#  'material': 40,
#  'care': 41,
#  'technology': 42,
#  'mr': 43,
#  'top': 44,
#  'south': 45,
#  'drop': 46,
#  'along': 47,
#  'carry': 48,
#  'weight': 49,
#  'trouble': 50,
#  'test': 51,
#  'charge': 52,
#  'eye': 53,
#  'while': 54,
#  'knowledge': 55,
#  'reflect': 56,
#  'game': 57,
#  'moment': 58,
#  'nor': 59,
#  'require': 60,
#  'white': 61,
#  'team': 62,
#  'sport': 63,
#  'each': 64,
#  'onto': 65,
#  'whether': 66,
#  'support': 67,
#  'hit': 68,
#  'everybody': 69,
#  'share': 70,
#  'spend': 71,
#  'something': 72,
#  'ever': 73,
#  'growth': 74,
#  'reason': 75,
#  'seem': 76,
#  'market': 77,
#  'medical': 78,
#  'out': 79,
#  'its': 80,
#  'mention': 81,
#  'hard': 82,
#  'number': 83,
#  'him': 84,
#  'big': 85,
#  'mission': 86,
#  'great': 87,
#  'executive': 88,
#  'should': 89,
#  'all': 90,
#  'situation': 91,
#  'amount': 92,
#  'important': 93,
#  'sort': 94,
#  'kid': 95,
#  'near': 96,
#  'six': 97,
#  'why': 98,
#  'provide': 99,
#  'thank': 100,
#  'before': 101,
#  'film': 102,
#  'century': 103,
#  'thousand': 104,
#  'eight': 105,
#  'name': 106,
#  'article': 107,
#  'third': 108,
#  'through': 109,
#  'for': 110,
#  'tell': 111,
#  'every': 112,
#  'style': 113,
#  'else': 114,
#  'pay': 115,
#  'economy': 116,
#  'court': 117,
#  'decision': 118,
#  'ball': 119,
#  'trade': 120,
#  'least': 121,
#  'physical': 122,
#  'i': 123,
#  'by': 124,
#  'early': 125,
#  'me': 126,
#  'professional': 127,
#  'money': 128,
#  'country': 129,
#  'get': 130,
#  'hundred': 131,
#  'suddenly': 132,
#  'could': 133,
#  'nature': 134,
#  'middle': 135,
#  'dinner': 136,
#  'who': 137,
#  'almost': 138,
#  'hand': 139,
#  'government': 140,
#  'never': 141,
#  'from': 142,
#  'avoid': 143,
#  'large': 144,
#  'cause': 145,
#  'instead': 146,
#  'music': 147,
#  'cost': 148,
#  'bad': 149,
#  'young': 150,
#  'american': 151,
#  'bank': 152,
#  'back': 153,
#  'level': 154,
#  'trial': 155,
#  'now': 156,
#  'above': 157,
#  'allow': 158,
#  'family': 159,
#  'shoulder': 160,
#  'life': 161,
#  'because': 162,
#  'rock': 163,
#  'north': 164,
#  'thought': 165,
#  'likely': 166,
#  'rest': 167,
#  'item': 168,
#  'or': 169,
#  'pass': 170,
#  'officer': 171,
#  'suggest': 172,
#  'figure': 173,
#  'but': 174,
#  'face': 175,
#  'base': 176,
#  'what': 177,
#  'myself': 178,
#  'claim': 179,
#  'meet': 180,
#  'chance': 181,
#  'answer': 182,
#  'home': 183,
#  'simple': 184,
#  'no': 185,
#  'rule': 186,
#  'gun': 187,
#  'these': 188,
#  'set': 189,
#  'throughout': 190,
#  'class': 191,
#  'ok': 192,
#  'public': 193,
#  'follow': 194,
#  'might': 195,
#  'question': 196,
#  'yard': 197,
#  'when': 198,
#  'administration': 199,
#  'main': 200,
#  'down': 201,
#  'take': 202,
#  'he': 203,
#  'list': 204,
#  'we': 205,
#  'learn': 206,
#  'they': 207,
#  'news': 208,
#  'whom': 209,
#  'fly': 210,
#  'plant': 211,
#  'risk': 212,
#  'sometimes': 213,
#  'past': 214,
#  'identify': 215,
#  'majority': 216,
#  'boy': 217,
#  'politics': 218,
#  'look': 219,
#  'lose': 220,
#  'several': 221,
#  'responsibility': 222,
#  'concern': 223,
#  'hospital': 224,
#  'factor': 225,
#  'those': 226,
#  'individual': 227,
#  'firm': 228,
#  'report': 229,
#  'town': 230,
#  'candidate': 231,
#  'later': 232,
#  'really': 233,
#  'friend': 234,
#  'evening': 235,
#  'process': 236,
#  'tv': 237,
#  'believe': 238,
#  'national': 239,
#  'simply': 240,
#  'single': 241,
#  'none': 242,
#  'especially': 243,
#  'sign': 244,
#  'nation': 245,
#  'fear': 246,
#  'player': 247,
#  'memory': 248,
#  'best': 249,
#  'resource': 250,
#  'fund': 251,
#  'couple': 252,
#  'space': 253,
#  'pm': 254,
#  'leg': 255,
#  'can': 256,
#  'have': 257,
#  'street': 258,
#  'theory': 259,
#  'significant': 260,
#  'remember': 261,
#  'treat': 262,
#  'against': 263,
#  'return': 264,
#  'record': 265,
#  'book': 266,
#  'write': 267,
#  'agreement': 268,
#  'positive': 269,
#  'piece': 270,
#  'leader': 271,
#  'various': 272,
#  'still': 273,
#  'yes': 274,
#  'station': 275,
#  'social': 276,
#  'anything': 277,
#  'star': 278,
#  'budget': 279,
#  'half': 280,
#  'in': 281,
#  'once': 282,
#  'able': 283,
#  'hair': 284,
#  'attorney': 285,
#  'mind': 286,
#  'she': 287,
#  'week': 288,
#  'continue': 289,
#  'special': 290,
#  'house': 291,
#  'walk': 292,
#  'and': 293,
#  'hotel': 294,
#  'machine': 295,
#  'message': 296,
#  'hour': 297,
#  'finish': 298,
#  'cold': 299,
#  'night': 300,
#  'network': 301,
#  'let': 302,
#  'role': 303,
#  'project': 304,
#  'voice': 305,
#  'determine': 306,
#  'be': 307,
#  'point': 308,
#  'peace': 309,
#  'account': 310,
#  'toward': 311,
#  'campaign': 312,
#  'recently': 313,
#  'win': 314,
#  'statement': 315,
#  'investment': 316,
#  'receive': 317,
#  'room': 318,
#  'central': 319,
#  'wide': 320,
#  'state': 321,
#  'general': 322,
#  'future': 323,
#  'show': 324,
#  'baby': 325,
#  'oil': 326,
#  'million': 327,
#  'current': 328,
#  'tough': 329,
#  'conference': 330,
#  'work': 331,
#  'manage': 332,
#  'newspaper': 333,
#  'increase': 334,
#  'sit': 335,
#  'respond': 336,
#  'radio': 337,
#  'same': 338,
#  'successful': 339,
#  'model': 340,
#  'billion': 341,
#  'west': 342,
#  'population': 343,
#  'job': 344,
#  'certain': 345,
#  'at': 346,
#  'feel': 347,
#  'add': 348,
#  'travel': 349,
#  'career': 350,
#  'two': 351,
#  'reach': 352,
#  'soldier': 353,
#  'outside': 354,
#  'indicate': 355,
#  'rather': 356,
#  'affect': 357,
#  'professor': 358,
#  'my': 359,
#  'happen': 360,
#  'easy': 361,
#  'glass': 362,
#  'seek': 363,
#  'world': 364,
#  'southern': 365,
#  'particular': 366,
#  'range': 367,
#  'sure': 368,
#  'it': 369,
#  'us': 370,
#  'system': 371,
#  'rich': 372,
#  'left': 373,
#  'blood': 374,
#  'beat': 375,
#  'arrive': 376,
#  'interest': 377,
#  'matter': 378,
#  'movement': 379,
#  'choice': 380,
#  'senior': 381,
#  'idea': 382,
#  'last': 383,
#  'even': 384,
#  'herself': 385,
#  'interesting': 386,
#  'himself': 387,
#  'crime': 388,
#  'partner': 389,
#  'bit': 390,
#  'open': 391,
#  'land': 392,
#  'degree': 393,
#  'building': 394,
#  'assume': 395,
#  'find': 396,
#  'media': 397,
#  'expert': 398,
#  'include': 399,
#  'more': 400,
#  'body': 401,
#  'heavy': 402,
#  'ask': 403,
#  'laugh': 404,
#  'according': 405,
#  'production': 406,
#  'community': 407,
#  'the': 408,
#  'only': 409,
#  'also': 410,
#  'major': 411,
#  'protect': 412,
#  'impact': 413,
#  'loss': 414,
#  'available': 415,
#  'perhaps': 416,
#  'create': 417,
#  'enjoy': 418,
#  'with': 419,
#  'just': 420,
#  'among': 421,
#  'health': 422,
#  'sister': 423,
#  'region': 424,
#  'develop': 425,
#  'scene': 426,
#  'imagine': 427,
#  'soon': 428,
#  'art': 429,
#  'page': 430,
#  'writer': 431,
#  'kitchen': 432,
#  'foreign': 433,
#  'bag': 434,
#  'grow': 435,
#  'four': 436,
#  'business': 437,
#  'three': 438,
#  'rate': 439,
#  'one': 440,
#  'quality': 441,
#  'garden': 442,
#  'then': 443,
#  'call': 444,
#  'themselves': 445,
#  'gas': 446,
#  'painting': 447,
#  'turn': 448,
#  'event': 449,
#  'story': 450,
#  'usually': 451,
#  'admit': 452,
#  'popular': 453,
#  'place': 454,
#  'run': 455,
#  'part': 456,
#  'this': 457,
#  'organization': 458,
#  'morning': 459,
#  'wind': 460,
#  'song': 461,
#  'school': 462,
#  'bed': 463,
#  'red': 464,
#  'keep': 465,
#  'language': 466,
#  'evidence': 467,
#  'mother': 468,
#  'always': 469,
#  'energy': 470,
#  'move': 471,
#  'people': 472,
#  'pretty': 473,
#  'case': 474,
#  'alone': 475,
#  'father': 476,
#  'heart': 477,
#  'beyond': 478,
#  'study': 479,
#  'dream': 480,
#  'will': 481,
#  'challenge': 482,
#  'prepare': 483,
#  'series': 484,
#  'animal': 485,
#  'difficult': 486,
#  'consumer': 487,
#  'course': 488,
#  'stuff': 489,
#  'sound': 490,
#  'phone': 491,
#  'issue': 492,
#  'drug': 493,
#  'offer': 494,
#  'mrs': 495,
#  'entire': 496,
#  'without': 497,
#  'church': 498,
#  'child': 499,
#  'human': 500,
#  'fact': 501,
#  'fire': 502,
#  'hot': 503,
#  'other': 504,
#  'structure': 505,
#  'stop': 506,
#  'force': 507,
#  'man': 508,
#  'cup': 509,
#  'accept': 510,
#  'decide': 511,
#  'full': 512,
#  'light': 513,
#  'quickly': 514,
#  'effort': 515,
#  'son': 516,
#  'good': 517,
#  'control': 518,
#  'owner': 519,
#  'size': 520,
#  'less': 521,
#  'draw': 522,
#  'board': 523,
#  'inside': 524,
#  'word': 525,
#  'commercial': 526,
#  'read': 527,
#  'go': 528,
#  'way': 529,
#  'city': 530,
#  'federal': 531,
#  'away': 532,
#  'benefit': 533,
#  'smile': 534,
#  'year': 535,
#  'president': 536,
#  'try': 537,
#  'war': 538,
#  'put': 539,
#  'car': 540,
#  'forget': 541,
#  'artist': 542,
#  'her': 543,
#  'history': 544,
#  'order': 545,
#  'dark': 546,
#  'group': 547,
#  'drive': 548,
#  'summer': 549,
#  'huge': 550,
#  'whose': 551,
#  'again': 552,
#  'true': 553,
#  'training': 554,
#  'off': 555,
#  'generation': 556,
#  'former': 557,
#  'itself': 558,
#  'as': 559,
#  'threat': 560,
#  'whatever': 561,
#  'exactly': 562,
#  'nearly': 563,
#  'yet': 564,
#  'nice': 565,
#  'see': 566,
#  'price': 567,
#  'someone': 568,
#  'pick': 569,
#  'water': 570,
#  'republican': 571,
#  'about': 572,
#  'brother': 573,
#  'present': 574,
#  'catch': 575,
#  'agent': 576,
#  'tonight': 577,
#  'together': 578,
#  'ago': 579,
#  'though': 580,
#  'staff': 581,
#  'address': 582,
#  'explain': 583,
#  'relationship': 584,
#  'student': 585,
#  'hope': 586,
#  'since': 587,
#  'everything': 588,
#  'camera': 589,
#  'minute': 590,
#  'over': 591,
#  'girl': 592,
#  'police': 593,
#  'behavior': 594,
#  'finally': 595,
#  'wear': 596,
#  'five': 597,
#  'skin': 598,
#  'others': 599,
#  'may': 600,
#  'modern': 601,
#  'his': 602,
#  'parent': 603,
#  'guy': 604,
#  'enter': 605,
#  'citizen': 606,
#  'stock': 607,
#  'teacher': 608,
#  'per': 609,
#  'fall': 610,
#  'start': 611,
#  'beautiful': 612,
#  'lot': 613,
#  'action': 614,
#  'success': 615,
#  'until': 616,
#  'next': 617,
#  'ten': 618,
#  'movie': 619,
#  'describe': 620,
#  'husband': 621,
#  'operation': 622,
#  'strong': 623,
#  'worry': 624,
#  'time': 625,
#  'safe': 626,
#  'certainly': 627,
#  'audience': 628,
#  'interview': 629,
#  'east': 630,
#  'wife': 631,
#  'day': 632,
#  'floor': 633,
#  'raise': 634,
#  'activity': 635,
#  'better': 636,
#  'reveal': 637,
#  'short': 638,
#  'most': 639,
#  'ahead': 640,
#  'recognize': 641,
#  'act': 642,
#  'notice': 643,
#  'play': 644,
#  'prevent': 645,
#  'specific': 646,
#  'bar': 647,
#  'participant': 648,
#  'example': 649,
#  'unit': 650,
#  'both': 651,
#  'into': 652,
#  'well': 653,
#  'political': 654,
#  'within': 655,
#  'remain': 656,
#  'however': 657,
#  'focus': 658,
#  'attack': 659,
#  'military': 660,
#  'born': 661,
#  'source': 662,
#  'standard': 663,
#  'color': 664,
#  'stay': 665,
#  'leave': 666,
#  'cover': 667,
#  'score': 668,
#  'establish': 669,
#  'season': 670,
#  'you': 671,
#  'happy': 672,
#  'everyone': 673,
#  'doctor': 674,
#  'know': 675,
#  'effect': 676,
#  'design': 677,
#  'like': 678,
#  'our': 679,
#  'road': 680,
#  'approach': 681,
#  'clearly': 682,
#  'law': 683,
#  'probably': 684,
#  'feeling': 685,
#  'rise': 686,
#  'woman': 687,
#  'area': 688,
#  'whole': 689,
#  'consider': 690,
#  'recent': 691,
#  'speech': 692,
#  'power': 693,
#  'magazine': 694,
#  'across': 695,
#  'goal': 696,
#  'field': 697,
#  'such': 698,
#  'pull': 699,
#  'mean': 700,
#  'value': 701,
#  'truth': 702,
#  'opportunity': 703,
#  'total': 704,
#  'say': 705,
#  'fine': 706,
#  'end': 707,
#  'black': 708,
#  'suffer': 709,
#  'very': 710,
#  'choose': 711,
#  'box': 712,
#  'a': 713,
#  'where': 714,
#  'tree': 715,
#  'necessary': 716,
#  'view': 717,
#  'if': 718,
#  'author': 719,
#  'scientist': 720,
#  'change': 721,
#  'any': 722,
#  'image': 723,
#  'plan': 724,
#  'method': 725,
#  'term': 726,
#  'often': 727,
#  'begin': 728,
#  'director': 729,
#  'under': 730,
#  'become': 731,
#  'stage': 732,
#  'long': 733,
#  'prove': 734,
#  'similar': 735,
#  'form': 736,
#  'old': 737,
#  'discussion': 738,
#  'on': 739,
#  'science': 740,
#  'reduce': 741,
#  'customer': 742,
#  'serve': 743,
#  'indeed': 744,
#  'direction': 745,
#  'democratic': 746,
#  'stand': 747,
#  'hold': 748,
#  'relate': 749,
#  'during': 750,
#  'front': 751,
#  'must': 752,
#  'paper': 753,
#  'research': 754,
#  'which': 755,
#  'sense': 756,
#  'much': 757,
#  'international': 758,
#  'ground': 759,
#  'despite': 760,
#  'apply': 761,
#  'upon': 762,
#  'around': 763,
#  'many': 764,
#  'table': 765,
#  'surface': 766,
#  'buy': 767,
#  'join': 768,
#  'information': 769,
#  'to': 770,
#  'save': 771,
#  'month': 772,
#  'exist': 773,
#  'race': 774,
#  'teach': 775,
#  'wait': 776,
#  'eat': 777,
#  'behind': 778,
#  'cell': 779,
#  'maybe': 780,
#  'door': 781,
#  'improve': 782,
#  'actually': 783,
#  'institution': 784,
#  'help': 785,
#  'civil': 786,
#  'section': 787,
#  'discover': 788,
#  'authority': 789,
#  'too': 790,
#  'your': 791,
#  'employee': 792,
#  'particularly': 793,
#  'task': 794,
#  'think': 795,
#  'subject': 796,
#  'quite': 797,
#  'after': 798,
#  'data': 799,
#  'worker': 800,
#  'real': 801,
#  'vote': 802,
#  'right': 803,
#  'reality': 804,
#  'speak': 805,
#  'property': 806,
#  'tax': 807,
#  'do': 808,
#  'culture': 809,
#  'daughter': 810,
#  'of': 811,
#  'clear': 812,
#  'check': 813,
#  'yourself': 814,
#  'want': 815,
#  'official': 816,
#  'wall': 817,
#  'defense': 818,
#  'ability': 819,
#  'program': 820,
#  'bring': 821,
#  'few': 822,
#  'edge': 823,
#  'first': 824,
#  'coach': 825,
#  'arm': 826,
#  'between': 827,
#  'blue': 828,
#  'industry': 829,
#  'listen': 830,
#  'fight': 831,
#  'different': 832,
#  'maintain': 833,
#  'them': 834,
#  'close': 835,
#  'including': 836,
#  'late': 837,
#  'picture': 838,
#  'position': 839,
#  'guess': 840,
#  'seven': 841,
#  'bill': 842,
#  'note': 843,
#  'agency': 844,
#  'sea': 845,
#  'financial': 846,
#  'management': 847,
#  'talk': 848,
#  'serious': 849,
#  'attention': 850,
#  'experience': 851,
#  'education': 852,
#  'than': 853,
#  'cultural': 854,
#  'poor': 855,
#  'religious': 856,
#  'second': 857,
#  'understand': 858,
#  'skill': 859,
#  'produce': 860,
#  'development': 861,
#  'analysis': 862,
#  'today': 863,
#  'anyone': 864,
#  'personal': 865,
#  'sing': 866,
#  'adult': 867,
#  'service': 868,
#  'debate': 869,
#  'possible': 870,
#  'television': 871,
#  'congress': 872,
#  'some': 873,
#  'fish': 874,
#  'miss': 875,
#  'contain': 876,
#  'push': 877,
#  'traditional': 878,
#  'own': 879,
#  'type': 880,
#  'here': 881,
#  'practice': 882,
#  'chair': 883,
#  'manager': 884,
#  'compare': 885,
#  'final': 886,
#  'wrong': 887,
#  'condition': 888,
#  'represent': 889,
#  'so': 890,
#  'trip': 891,
#  'enough': 892,
#  'thus': 893,
#  'local': 894,
#  'member': 895,
#  'give': 896,
#  'economic': 897,
#  'democrat': 898,
#  'difference': 899,
#  'make': 900,
#  'tend': 901,
#  'need': 902,
#  'seat': 903,
#  'party': 904,
#  'air': 905,
#  'college': 906,
#  'throw': 907,
#  'argue': 908,
#  'another': 909,
#  'that': 910,
#  'side': 911,
#  'shake': 912,
#  'strategy': 913,
#  'their': 914,
#  'high': 915,
#  'small': 916,
#  'decade': 917,
#  'marriage': 918,
#  'spring': 919,
#  'pattern': 920,
#  'little': 921,
#  'product': 922,
#  'center': 923,
#  'build': 924,
#  'send': 925,
#  'environmental': 926,
#  'window': 927,
#  'watch': 928,
#  'there': 929,
#  'discuss': 930,
#  'although': 931,
#  'dog': 932,
#  'cut': 933,
#  'response': 934,
#  'use': 935,
#  'common': 936,
#  'step': 937,
#  'treatment': 938,
#  'low': 939,
#  'foot': 940,
#  'wish': 941,
#  'capital': 942,
#  'new': 943,
#  'option': 944,
#  'computer': 945,
#  'environment': 946,
#  'deep': 947,
#  'natural': 948,
#  'result': 949,
#  'person': 950,
#  'forward': 951,
#  'pressure': 952,
#  'office': 953,
#  'live': 954,
#  'involve': 955,
#  'line': 956,
#  'wonder': 957,
#  'free': 958,
#  'sell': 959,
#  'food': 960,
#  'not': 961,
#  'either': 962,
#  'age': 963,
#  'western': 964,
#  'collection': 965,
#  'somebody': 966,
#  'appear': 967,
#  'measure': 968,
#  'green': 969,
#  'hear': 970,
#  'expect': 971,
#  'company': 972}

# %%
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# %%
X_train_seq[0], X_train[0]
# Out:
# ([2,
#   797,
#   478,
#   587,
#   668,
#   532,
#   756,
#   20,
#   626,
#   877,
#   84,
#   131,
#   331,
#   428,
#   798,
#   799,
#   800,
#   57],
#  'Visit quite beyond since. Score away sense ready safe push. Him hundred work soon after data worker game.')

# %%
# Padding -> (50) => 50'den kısa cümleler için başına ya da sonuna 0 ekle. (0 => Boşluk) || 50'den büyükse 50şerlik arrayleri böl.
from tensorflow.keras.preprocessing.sequence import pad_sequences

X_train_pad = pad_sequences(X_train_seq, maxlen=50, padding="post")
X_test_pad = pad_sequences(X_test_seq, maxlen=50, padding="post")
#

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=10000, output_dim=64, input_length=50), #Kelimeleri vektörlere çevirir.
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)), # Bidirectional -> Soldan sağa ve sağdan sola, #LSTM => Long short-term Memory -> 128 nöronluk çıktı.
    tf.keras.layers.Dense(32, activation="relu"), # Non-linear bi yapı kurarak gerçek hayata yaklaşmak. max(0,z)
    tf.keras.layers.Dropout(0.4), # Her çalıştırmada rastgele verilen oranda nöronu kapatır.
    tf.keras.layers.Dense(1, activation="linear") # linear => f(x)=x # 1-> Çıktı adet sayısı.
])
# Model eğitimi öncesi özellikleri belirleme.
model.compile(loss="mean_squared_error", metrics=['mae'], optimizer="adam")

history = model.fit(X_train_pad, y_train, epochs=3, validation_data=(X_test_pad, y_test), batch_size=2)
# Out:
# Epoch 1/3
# C:\Users\deniz\anaconda3\envs\env_1\lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1404/1404 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - loss: 10.7129 - mae: 2.6682 - val_loss: 6.7005 - val_mae: 2.2390
# Epoch 2/3
# 1404/1404 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - loss: 8.8193 - mae: 2.4739 - val_loss: 7.0669 - val_mae: 2.2787
# Epoch 3/3
# 1404/1404 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - loss: 7.1954 - mae: 2.1956 - val_loss: 8.0125 - val_mae: 2.3746

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 50, 64)              │         640,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 128)                 │          66,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,130,629 (8.13 MB)
#  Trainable params: 710,209 (2.71 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,420,420 (5.42 MB)
