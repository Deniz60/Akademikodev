# %%
# !pip install scikit_learn pandas
# Out:
# Collecting scikit_learn
#   Using cached scikit_learn-1.0.2-cp37-cp37m-win_amd64.whl (7.1 MB)
# Collecting pandas
#   Using cached pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from scikit_learn) (3.1.0)
# Collecting scipy>=1.1.0
#   Using cached scipy-1.7.3-cp37-cp37m-win_amd64.whl (34.1 MB)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from scikit_learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from scikit_learn) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\deniz\anaconda3\envs\env_1\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.17.0)
# Installing collected packages: scipy, scikit_learn, pandas
# Successfully installed pandas-1.3.5 scikit_learn-1.0.2 scipy-1.7.3

# %%
from sklearn.datasets import make_blobs

# %%
X,y_true =make_blobs(n_samples=300, centers=4, random_state=42)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,3))
plt.scatter(X[:,0],X[:,1], c=y_true, s=20, alpha=0.5) 
plt.show()

# %%
import pandas as pd

# %%
df=pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X = df[[ "Annual Income (k$)", "Spending Score (1-100)" ]].values

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=3, random_state=42)
model.fit(X)
# Out:
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
y=model.predict(X)

# %%
model.cluster_centers_
# Out:
# array([[87.        , 18.63157895],
#        [86.53846154, 82.12820513],
#        [44.15447154, 49.82926829]])

# %%
plt.figure(figsize=(5,3))
plt.scatter(      X[:,0], X[:,1], c=y, s=20, alpha=0.5  )
plt.scatter(  model.cluster_centers_[:,0], model.cluster_centers_[:,1], c="red", marker="X", s=250       )
plt.show()

# %%
# k- means n_cluster degerinin en iyi değerini bulmak

# %%
# elbow method
# silhouette method
# davies bouldin method

# %%
# Her k-means modelinde "inertia" değeri var.
def elbow_method():
    inertias = []
    for k in range(2,11): #2,3,4,5
        model = KMeans(n_clusters=k, random_state=42)
        model.fit(X)
        inertias.append(model.inertia_)
    plt.figure(figsize=(5,3))
    plt.plot(range(2,11), inertias)
    print(inertias)

# %%
elbow_method()
# Out:
# [183653.32894736837, 106348.37306211118, 73880.64496247197, 44448.45544793371, 40825.16946386946, 33642.579220779226, 26686.83778518779, 24766.47160979344, 23103.122085983916]
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Silhouette Method -> Hem kendi merkezime yakınlık hem diğer merkezlere uzaklığa dikkat eder.

# %%
from sklearn.metrics import silhouette_score

# %%
def silh_method():
    scores = []
    for k in range(2,11):
        model = KMeans(n_clusters=k, random_state=42)
        y = model.fit_predict(X)
        scores.append( silhouette_score(X,y)  )
    plt.figure(figsize=(5,3))
    plt.plot(range(2,11), scores)
    plt.show()

# %%
silh_method()
# Out:
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\deniz\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
